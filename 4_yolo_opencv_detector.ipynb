# %% [markdown]
# # **Instructions**:
#
# ### 1 - Open your game that you want to perform detections
# ### 2 - In the game window, get the name of it's title bar
# ### 3 - Update the variable "window_name" with the game title bar name
# ### 4 - Run all cells to start detecting objects using your trained model

# %%
import numpy as np
import win32gui, win32ui, win32con
from PIL import Image
from time import sleep
import cv2 as cv
import os
import random

# %%
class WindowCapture:
    w = 0
    h = 0
    hwnd = None

    def __init__(self, window_name):
        self.hwnd = win32gui.FindWindow(None, window_name)
        if not self.hwnd:
            raise Exception('Window not found: {}'.format(window_name))

        window_rect = win32gui.GetWindowRect(self.hwnd)
        self.w = window_rect[2] - window_rect[0]
        self.h = window_rect[3] - window_rect[1]

        border_pixels = 8
        titlebar_pixels = 30
        self.w = self.w - (border_pixels * 2)
        self.h = self.h - titlebar_pixels - border_pixels
        self.cropped_x = border_pixels
        self.cropped_y = titlebar_pixels

    def get_screenshot(self):
        wDC = win32gui.GetWindowDC(self.hwnd)
        dcObj = win32ui.CreateDCFromHandle(wDC)
        cDC = dcObj.CreateCompatibleDC()
        dataBitMap = win32ui.CreateBitmap()
        dataBitMap.CreateCompatibleBitmap(dcObj, self.w, self.h)
        cDC.SelectObject(dataBitMap)
        cDC.BitBlt((0, 0), (self.w, self.h), dcObj, (self.cropped_x, self.cropped_y), win32con.SRCCOPY)

        signedIntsArray = dataBitMap.GetBitmapBits(True)
        img = np.frombuffer(signedIntsArray, dtype='uint8')
        img.shape = (self.h, self.w, 4)

        dcObj.DeleteDC()
        cDC.DeleteDC()
        win32gui.ReleaseDC(self.hwnd, wDC)
        win32gui.DeleteObject(dataBitMap.GetHandle())

        img = img[...,:3]
        img = np.ascontiguousarray(img) 
            
        return img

    def generate_image_dataset(self):
        if not os.path.exists("images"):
            os.mkdir("images")
        while(True):
            img = self.get_screenshot()
            im = Image.fromarray(img[..., [2, 1, 0]])
            im.save(f"./images/img_{len(os.listdir('images'))}.jpeg")
            sleep(1)
    
    def get_window_size(self):
        return (self.w, self.h)

# %%
class ImageProcessor:
    W = 0
    H = 0
    net = None
    ln = None
    classes = {}
    colors = []

    def __init__(self, img_size, cfg_file, weights_file):
        np.random.seed(42)
        self.net = cv.dnn.readNetFromDarknet(cfg_file, weights_file)
        self.net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
        self.ln = self.net.getLayerNames()
        self.ln = [self.ln[i-1] for i in self.net.getUnconnectedOutLayers()]
        self.W = img_size[0]
        self.H = img_size[1]
        
        with open('yolov4-tiny/obj.names', 'r') as file:
            lines = file.readlines()
        for i, line in enumerate(lines):
            self.classes[i] = line.strip()
        
        # If you plan to utilize more than six classes, please include additional colors in this list.
        self.colors = [
            (0, 0, 255), 
            (0, 255, 0), 
            (255, 0, 0), 
            (255, 255, 0), 
            (255, 0, 255), 
            (0, 255, 255)
        ]
        

    def proccess_image(self, img):

        blob = cv.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
        self.net.setInput(blob)
        outputs = self.net.forward(self.ln)
        outputs = np.vstack(outputs)
        
        coordinates = self.get_coordinates(outputs, 0.5)

        self.draw_identified_objects(img, coordinates)

        return coordinates

    def get_coordinates(self, outputs, conf):

        boxes = []
        confidences = []
        classIDs = []

        for output in outputs:
            scores = output[5:]
            
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > conf:
                x, y, w, h = output[:4] * np.array([self.W, self.H, self.W, self.H])
                p0 = int(x - w//2), int(y - h//2)
                boxes.append([*p0, int(w), int(h)])
                confidences.append(float(confidence))
                classIDs.append(classID)

        indices = cv.dnn.NMSBoxes(boxes, confidences, conf, conf-0.1)

        if len(indices) == 0:
            return []

        coordinates = []
        for i in indices.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            coordinates.append({'x': x, 'y': y, 'w': w, 'h': h, 'class': classIDs[i], 'class_name': self.classes[classIDs[i]]})
        return coordinates

    def draw_identified_objects(self, img, coordinates):
        for coordinate in coordinates:
            x = coordinate['x']
            y = coordinate['y']
            w = coordinate['w']
            h = coordinate['h']
            classID = coordinate['class']
            
            color = self.colors[classID]
            
            cv.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv.putText(img, self.classes[classID], (x, y - 10), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        cv.imshow('window',  img)

# %%
# Run this cell to initiate detections using the trained model.

window_name = "PetStar£¨V1.16.52£©"
cfg_file_name = "./yolov4-tiny/yolov4-tiny-custom.cfg"
weights_file_name = "yolov4-tiny-custom_last.weights"

wincap = WindowCapture(window_name)
improc = ImageProcessor(wincap.get_window_size(), cfg_file_name, weights_file_name)

while(True):
    
    ss = wincap.get_screenshot()
    
    if cv.waitKey(1) == ord('q'):
        cv.destroyAllWindows()
        break

    coordinates = improc.proccess_image(ss)
    
    for coordinate in coordinates:
        print(coordinate)
    print()
    
    # If you have limited computer resources, consider adding a sleep delay between detections.
    # sleep(0.2)

print('Finished.')
# Out:
# {'x': 280, 'y': 146, 'w': 87, 'h': 75, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 274, 'y': 136, 'w': 85, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 277, 'y': 141, 'w': 79, 'h': 71, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 284, 'y': 143, 'w': 81, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 292, 'y': 145, 'w': 81, 'h': 73, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 300, 'y': 151, 'w': 79, 'h': 69, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 300, 'y': 148, 'w': 86, 'h': 74, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 318, 'y': 157, 'w': 89, 'h': 73, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 330, 'y': 149, 'w': 83, 'h': 74, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 322, 'y': 147, 'w': 85, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 318, 'y': 147, 'w': 95, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 327, 'y': 150, 'w': 84, 'h': 70, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 341, 'y': 154, 'w': 69, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 340, 'y': 165, 'w': 89, 'h': 69, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 339, 'y': 160, 'w': 90, 'h': 73, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 335, 'y': 149, 'w': 78, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 322, 'y': 148, 'w': 92, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 317, 'y': 145, 'w': 85, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x':
 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 625, 'y': 14, 'w': 86, 'h': 58, 'class': np.int64(0), 'class_name': 'pig'}
# {'x': 375, 'y': 150, 'w': 77, 'h': 67, 'class': np.int64(0), 'class_name': 'pig'}
#
#
# {'x': 356, 'y': 155, 'w': 84, 'h': 66, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 354, 'y': 160, 'w': 91, 'h': 65, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 353, 'y': 161, 'w': 92, 'h': 60, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 335, 'y': 161, 'w': 98, 'h': 69, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 325, 'y': 147, 'w': 95, 'h': 80, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 310, 'y': 145, 'w': 103, 'h': 77, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 302, 'y': 141, 'w': 98, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 290, 'y': 156, 'w': 82, 'h': 71, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 278, 'y': 161, 'w': 83, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 283, 'y': 160, 'w': 83, 'h': 70, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 287, 'y': 166, 'w': 86, 'h': 73, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 286, 'y': 164, 'w': 100, 'h': 79, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 291, 'y': 165, 'w': 94, 'h': 78, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 300, 'y': 168, 'w': 101, 'h': 78, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 298, 'y': 168, 'w': 111, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 287, 'y': 156, 'w': 97, 'h': 83, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 271, 'y': 165, 'w': 95, 'h': 80, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 260, 'y': 187, 'w': 76, 'h': 64, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 259, 'y': 184, 'w': 79, 'h': 68, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 265, 'y': 183, 'w': 83, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 274, 'y': 191, 'w': 79, 'h': 69, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 276, 'y': 190, 'w': 84, 'h': 74, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 278, 'y': 188, 'w': 81, 'h': 73, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 273, 'y': 183, 'w': 86, 'h': 81, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 270, 'y': 182, 'w': 77, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 263, 'y': 178, 'w': 86, 'h': 76, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 263, 'y': 181, 'w': 75, 'h': 67, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 260, 'y': 178, 'w': 81, 'h': 74, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 278, 'y': 186, 'w': 75, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 288, 'y': 193, 'w': 88, 'h': 77, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 283, 'y': 191, 'w': 77, 'h': 75, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 276, 'y': 184, 'w': 93, 'h': 83, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 276, 'y': 183, 'w': 90, 'h': 84, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 279, 'y': 195, 'w': 80, 'h': 72, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 268, 'y': 206, 'w': 82, 'h': 64, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 269, 'y': 206, 'w': 82, 'h': 66, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 262, 'y': 209, 'w': 88, 'h': 64, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 270, 'y': 204, 'w': 80, 'h': 69, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 271, 'y': 210, 'w': 87, 'h': 70, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 285, 'y': 195, 'w': 73, 'h': 75, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 291, 'y': 186, 'w': 99, 'h': 73, 'class': np.int64(0), 'class_name': 'pig'}
#
# {'x': 287, 'y': 207, 'w': 82, 'h': 63, 'class': np.int64(0), 'class_name': 'pig'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      15     cv.destroyAllWindows()
#      16     break
# ---> 18 coordinates = improc.proccess_image(ss)
#      20 for coordinate in coordinates:
#      21     print(coordinate)
#
# Cell In[3], line 38, in ImageProcessor.proccess_image(self, img)
#      36 blob = cv.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
#      37 self.net.setInput(blob)
# ---> 38 outputs = self.net.forward(self.ln)
#      39 outputs = np.vstack(outputs)
#      41 coordinates = self.get_coordinates(outputs, 0.5)
#
# KeyboardInterrupt:
